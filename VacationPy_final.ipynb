# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID               City      Lat       Lng  Max Temp  Humidity  \
# 0        0             itoman  26.1247  127.6694     27.43        55
# 1        1          papatowai -46.5619  169.4708     14.37        60
# 2        2  port-aux-francais -49.3500   70.2167      1.86        63
# 3        3          adamstown -25.0660 -130.1015     22.65        81
# 4        4         siwa oasis  29.2041   25.5195     21.27        75
#
#    Cloudiness  Wind Speed Country        Date
# 0          40        5.66      JP  1970-01-01
# 1           6        5.42      NZ  1970-01-01
# 2          66       11.90      TF  1970-01-01
# 3         100        4.23      PN  1970-01-01
# 4           0        2.87      EG  1970-01-01

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
map_plot_1 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True, 
    tiles = "OSM",
    size = "Humidity",
    frame_width = 800,
    frame_height = 600, 
    scale = 0.5,
    color = "City"
)

# Display the map
map_plot_1
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
ideal_weather_df = city_data_df.loc[(city_data_df["Max Temp"] < 27)
                                    & (city_data_df["Max Temp"] >21)
                                    & (city_data_df["Cloudiness"] > 0)
                                    & (city_data_df["Wind Speed"] > 4.5)]

# Drop any rows with null values
ideal_weather_df.dropna() 

# How many values are there now? [I ADDED THIS FOR ME//NOT IN STARTERCODE]
print(len(ideal_weather_df))

# Display sample data
ideal_weather_df
# Out:
# 35
#      City_ID               City      Lat       Lng  Max Temp  Humidity  \
# 12        12             uturoa -16.7333 -151.4333     26.56        78
# 29        29              lihue  21.9789 -159.3672     26.58        78
# 44        44           ishigaki  24.3448  124.1572     25.67        64
# 68        68               kone -21.0595  164.8658     25.37        45
# 73        73      haiku-pauwela  20.9219 -156.3051     26.13        70
# 91        91             touros  -5.1989  -35.4608     24.82        81
# 93        93            isangel -19.5500  169.2667     26.06        73
# 96        96        antsiranana -12.2787   49.2917     24.83        78
# 99        99      port mathurin -19.6833   63.4167     24.87        78
# 100      100              obock  12.2500   43.0833     21.66        78
# 146      146  wailua homesteads  22.0669 -159.3780     26.24        79
# 147      147      marsh harbour  26.5412  -77.0636     25.66        77
# 148      148            sechura  -5.5569  -80.8222     21.01        75
# 167      167           afaahiti -17.7500 -149.2833     26.70        82
# 235      235         nuku'alofa -21.1333 -175.2000     23.54        89
# 252      252       san patricio  28.0170  -97.5169     22.92        72
# 255      255              jijel  36.8205    5.7667     22.66        42
# 272      272             la foa -21.7108  165.8276     23.29        51
# 281      281             olinda  -8.0089  -34.8553     25.85        69
# 285      285           batabano  22.7164  -82.2881     24.34        81
# 311      311             acarau  -2.8856  -40.1200     26.26        81
# 344      344          al matlin  37.2452   10.0500     24.77        72
# 350      350            baillif  16.0202  -61.7463     25.72        84
# 366      366           misratah  32.3754   15.0925     23.31        71
# 378      378             hirara  24.8000  125.2833     25.31        60
# 379      379    arraial do cabo -22.9661  -42.0278     23.16        98
# 407      407              virac  13.6333  124.2167     25.30        75
# 423      423         cannonvale -20.2833  148.7000     25.66        51
# 441      441             loango  -4.6719   11.8312     25.81        94
# 474      474              alofi -19.0595 -169.9187     23.97        84
# 484      484  sao joao da barra -21.6403  -41.0511     23.23        89
# 500      500            kyabram -36.3167  145.0500     21.60        27
# 503      503         port pirie -33.1833  138.0167     23.26        32
# 508      508       port douglas -16.4833  145.4667     25.73        60
# 534      534            kavieng  -2.5744  150.7967     24.72        93
#
#      Cloudiness  Wind Speed Country        Date
# 12            8        6.36      PF  1970-01-01
# 29          100        4.63      US  1970-01-01
# 44           87        6.06      JP  1970-01-01
# 68            2        4.92      NC  1970-01-01
# 73           40        6.69      US  1970-01-01
# 91           20        6.26      BR  1970-01-01
# 93           40        4.63      VU  1970-01-01
# 96           96        7.30      MG  1970-01-01
# 99           12        7.00      MU  1970-01-01
# 100          80        6.32      DJ  1970-01-01
# 146         100        4.63      US  1970-01-01
# 147          95        9.07      BS  1970-01-01
# 148         100        7.11      PE  1970-01-01
# 167          40        8.22      PF  1970-01-01
# 235           5        8.14      TO  1970-01-01
# 252           4        9.13      US  1970-01-01
# 255          67        4.85      DZ  1970-01-01
# 272           2        4.90      NC  1970-01-01
# 281          40        5.66      BR  1970-01-01
# 285           2        5.89      CU  1970-01-01
# 311          93        7.18      BR  1970-01-01
# 344          54        7.92      TN  1970-01-01
# 350         100        6.08      GP  1970-01-01
# 366          81        4.63      LY  1970-01-01
# 378          52        5.98      JP  1970-01-01
# 379         100        4.67      BR  1970-01-01
# 407          92        4.97      PH  1970-01-01
# 423          21        5.33      AU  1970-01-01
# 441          75        5.66      CG  1970-01-01
# 474           5       10.25      NU  1970-01-01
# 484          96        6.05      BR  1970-01-01
# 500          99        8.51      AU  1970-01-01
# 503          11        4.58      AU  1970-01-01
# 508          98        5.01      AU  1970-01-01
# 534         100        4.87      PG  1970-01-01

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = ideal_weather_df[["City", "Country", "Lat", "Lng", "Humidity"]].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"]=""

# Display sample data
hotel_df
# Out:
#                   City Country      Lat       Lng  Humidity Hotel Name
# 12              uturoa      PF -16.7333 -151.4333        78
# 29               lihue      US  21.9789 -159.3672        78
# 44            ishigaki      JP  24.3448  124.1572        64
# 68                kone      NC -21.0595  164.8658        45
# 73       haiku-pauwela      US  20.9219 -156.3051        70
# 91              touros      BR  -5.1989  -35.4608        81
# 93             isangel      VU -19.5500  169.2667        73
# 96         antsiranana      MG -12.2787   49.2917        78
# 99       port mathurin      MU -19.6833   63.4167        78
# 100              obock      DJ  12.2500   43.0833        78
# 146  wailua homesteads      US  22.0669 -159.3780        79
# 147      marsh harbour      BS  26.5412  -77.0636        77
# 148            sechura      PE  -5.5569  -80.8222        75
# 167           afaahiti      PF -17.7500 -149.2833        82
# 235         nuku'alofa      TO -21.1333 -175.2000        89
# 252       san patricio      US  28.0170  -97.5169        72
# 255              jijel      DZ  36.8205    5.7667        42
# 272             la foa      NC -21.7108  165.8276        51
# 281             olinda      BR  -8.0089  -34.8553        69
# 285           batabano      CU  22.7164  -82.2881        81
# 311             acarau      BR  -2.8856  -40.1200        81
# 344          al matlin      TN  37.2452   10.0500        72
# 350            baillif      GP  16.0202  -61.7463        84
# 366           misratah      LY  32.3754   15.0925        71
# 378             hirara      JP  24.8000  125.2833        60
# 379    arraial do cabo      BR -22.9661  -42.0278        98
# 407              virac      PH  13.6333  124.2167        75
# 423         cannonvale      AU -20.2833  148.7000        51
# 441             loango      CG  -4.6719   11.8312        94
# 474              alofi      NU -19.0595 -169.9187        84
# 484  sao joao da barra      BR -21.6403  -41.0511        89
# 500            kyabram      AU -36.3167  145.0500        27
# 503         port pirie      AU -33.1833  138.0167        32
# 508       port douglas      AU -16.4833  145.4667        60
# 534            kavieng      PG  -2.5744  150.7967        93

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {"categories": "accommodation.hotel",\
        "apiKey":geoapify_key, \
        "limit":1
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    longitude = row["Lng"]
    latitude = row["Lat"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"

    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# uturoa - nearest hotel: Hawaiki Nui hotel
# lihue - nearest hotel: Kauai Palms
# ishigaki - nearest hotel: アートホテル石垣島
# kone - nearest hotel: Pacifik Appartels
# haiku-pauwela - nearest hotel: Inn At Mama's Fish House
# touros - nearest hotel: Pousada Atlântico
# isangel - nearest hotel: Tanna Lodge
# antsiranana - nearest hotel: Central
# port mathurin - nearest hotel: Escale Vacances
# obock - nearest hotel: No hotel found
# wailua homesteads - nearest hotel: Hilton Garden Inn Kauai Wailua Bay
# marsh harbour - nearest hotel: Lofty Fig Villas
# sechura - nearest hotel: Hospedaje Claritza
# afaahiti - nearest hotel: Omati Lodge
# nuku'alofa - nearest hotel: City Hotel
# san patricio - nearest hotel: No hotel found
# jijel - nearest hotel: Hôtel Louiza
# la foa - nearest hotel: Oasis de Tendea
# olinda - nearest hotel: Fidji Motel
# batabano - nearest hotel: No hotel found
# acarau - nearest hotel: No hotel found
# al matlin - nearest hotel: على جانب بيلي
# baillif - nearest hotel: Hôtel de Rocroy
# misratah - nearest hotel: الفندق السياحى
# hirara - nearest hotel: 古謝そば屋
# arraial do cabo - nearest hotel: No hotel found
# virac - nearest hotel: Marem Pension House
# cannonvale - nearest hotel: Whitsundays Rainforest Retreat
# loango - nearest hotel: Hotel des Aigles
# alofi - nearest hotel: Matavai Resort
# sao joao da barra - nearest hotel: Pousada Mediterrâneo
# kyabram - nearest hotel: No hotel found
# port pirie - nearest hotel: Ellen Hotel
# port douglas - nearest hotel: Mantra Aqueous Port Douglas
# kavieng - nearest hotel: Kavieng Hotel
#                   City Country      Lat       Lng  Humidity  \
# 12              uturoa      PF -16.7333 -151.4333        78
# 29               lihue      US  21.9789 -159.3672        78
# 44            ishigaki      JP  24.3448  124.1572        64
# 68                kone      NC -21.0595  164.8658        45
# 73       haiku-pauwela      US  20.9219 -156.3051        70
# 91              touros      BR  -5.1989  -35.4608        81
# 93             isangel      VU -19.5500  169.2667        73
# 96         antsiranana      MG -12.2787   49.2917        78
# 99       port mathurin      MU -19.6833   63.4167        78
# 100              obock      DJ  12.2500   43.0833        78
# 146  wailua homesteads      US  22.0669 -159.3780        79
# 147      marsh harbour      BS  26.5412  -77.0636        77
# 148            sechura      PE  -5.5569  -80.8222        75
# 167           afaahiti      PF -17.7500 -149.2833        82
# 235         nuku'alofa      TO -21.1333 -175.2000        89
# 252       san patricio      US  28.0170  -97.5169        72
# 255              jijel      DZ  36.8205    5.7667        42
# 272             la foa      NC -21.7108  165.8276        51
# 281             olinda      BR  -8.0089  -34.8553        69
# 285           batabano      CU  22.7164  -82.2881        81
# 311             acarau      BR  -2.8856  -40.1200        81
# 344          al matlin      TN  37.2452   10.0500        72
# 350            baillif      GP  16.0202  -61.7463        84
# 366           misratah      LY  32.3754   15.0925        71
# 378             hirara      JP  24.8000  125.2833        60
# 379    arraial do cabo      BR -22.9661  -42.0278        98
# 407              virac      PH  13.6333  124.2167        75
# 423         cannonvale      AU -20.2833  148.7000        51
# 441             loango      CG  -4.6719   11.8312        94
# 474              alofi      NU -19.0595 -169.9187        84
# 484  sao joao da barra      BR -21.6403  -41.0511        89
# 500            kyabram      AU -36.3167  145.0500        27
# 503         port pirie      AU -33.1833  138.0167        32
# 508       port douglas      AU -16.4833  145.4667        60
# 534            kavieng      PG  -2.5744  150.7967        93
#
#                              Hotel Name
# 12                    Hawaiki Nui hotel
# 29                          Kauai Palms
# 44                            アートホテル石垣島
# 68                    Pacifik Appartels
# 73             Inn At Mama's Fish House
# 91                    Pousada Atlântico
# 93                          Tanna Lodge
# 96                              Central
# 99                      Escale Vacances
# 100                      No hotel found
# 146  Hilton Garden Inn Kauai Wailua Bay
# 147                    Lofty Fig Villas
# 148                  Hospedaje Claritza
# 167                         Omati Lodge
# 235                          City Hotel
# 252                      No hotel found
# 255                        Hôtel Louiza
# 272                     Oasis de Tendea
# 281                         Fidji Motel
# 285                      No hotel found
# 311                      No hotel found
# 344                       على جانب بيلي
# 350                     Hôtel de Rocroy
# 366                      الفندق السياحى
# 378                               古謝そば屋
# 379                      No hotel found
# 407                 Marem Pension House
# 423      Whitsundays Rainforest Retreat
# 441                    Hotel des Aigles
# 474                      Matavai Resort
# 484                Pousada Mediterrâneo
# 500                      No hotel found
# 503                         Ellen Hotel
# 508         Mantra Aqueous Port Douglas
# 534                       Kavieng Hotel

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
hotel_map = hotel_df.hvplot.points("Lng",
                                    "Lat",
                                    geo = True, 
                                    color = "City",
                                    alpha = 0.8,
                                    size = "Humidity",
                                    tiles = "OSM",
                                    hover_cols = ["Hotel Name", "Country"]
)

# Display the map
hotel_map
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
