# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID               City      Lat       Lng  Max Temp  Humidity  \
# 0        0          hithadhoo  -0.6000   73.0833     27.18        83
# 1        1               uige  -7.6087   15.0613     19.36        89
# 2        2            aasiaat  68.7098  -52.8699    -10.96        91
# 3        3             tadine -21.5500  167.8833     22.62        67
# 4        4  port-aux-francais -49.3500   70.2167      4.39        94
#
#    Cloudiness  Wind Speed Country        Date
# 0          74        7.70      MV  1970-01-01
# 1          30        1.02      AO  1970-01-01
# 2          99        2.15      GL  1970-01-01
# 3          18        8.47      NC  1970-01-01
# 4         100       13.26      TF  1970-01-01

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
map_plot_1 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True, 
    tiles = "OSM",
    size = "Humidity",
    frame_width = 800,
    frame_height = 600, 
    scale = 0.5,
    color = "City"
)

# Display the map
map_plot_1
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
ideal_weather_df = city_data_df.loc[(city_data_df["Max Temp"] < 27)
                                    & (city_data_df["Max Temp"] >21)
                                    & (city_data_df["Cloudiness"] > 0)
                                    & (city_data_df["Wind Speed"] > 4.5)]

# Drop any rows with null values
ideal_weather_df.dropna() 

# How many values are there now? [I ADDED THIS FOR ME//NOT IN STARTERCODE]
print(len(ideal_weather_df))

# Display sample data
ideal_weather_df
# Out:
# 43
#      City_ID                     City      Lat       Lng  Max Temp  Humidity  \
# 3          3                   tadine -21.5500  167.8833     22.62        67
# 12        12                adamstown -25.0660 -130.1015     22.73        83
# 42        42                   uturoa -16.7333 -151.4333     26.39        79
# 56        56                    hobyo   5.3505   48.5268     25.57        85
# 93        93                     mana   5.6592  -53.7767     26.93        85
# 97        97                   avarua -21.2078 -159.7750     24.03        64
# 105      105                 tolanaro -25.0319   46.9987     24.04        88
# 125      125                    lihue  21.9789 -159.3672     26.77        75
# 128      128                     naze  28.3667  129.4833     23.51        53
# 135      135              west island -12.1568   96.8225     26.99        74
# 144      144                   acarau  -2.8856  -40.1200     26.19        76
# 146      146                 cabedelo  -6.9811  -34.8339     26.37        70
# 147      147                     kone -21.0595  164.8658     24.50        52
# 149      149           cabo san lucas  22.8909 -109.9124     25.61        70
# 150      150               vila velha -20.3297  -40.2925     25.97        83
# 160      160        wailua homesteads  22.0669 -159.3780     26.44        76
# 185      185              nova sintra  14.8667  -24.7167     23.10        75
# 196      196             saint-joseph -21.3667   55.6167     23.59        82
# 206      206              nova vicosa -17.8919  -39.3719     24.72        84
# 213      213  puerto baquerizo moreno  -0.9000  -89.6000     23.01        79
# 254      254                   tutoia  -2.7619  -42.2744     26.24        81
# 258      258                 alaghsas  17.0187    8.0168     24.95        14
# 261      261                 afaahiti -17.7500 -149.2833     26.93        76
# 274      274                  pitimbu  -7.4706  -34.8086     26.33        70
# 277      277         flying fish cove -10.4217  105.6791     26.82        78
# 332      332              antsiranana -12.2787   49.2917     24.94        77
# 341      341                  yeppoon -23.1333  150.7333     26.88        49
# 352      352                 westport  41.1415  -73.3579     21.02        60
# 361      361         wellington point -27.4833  153.2500     25.81        48
# 391      391                   hirara  24.8000  125.2833     26.92        57
# 408      408                 belmonte -15.8631  -38.8828     24.76        78
# 425      425             port douglas -16.4833  145.4667     25.49        65
# 442      442                    crane  31.3974 -102.3501     22.39        62
# 452      452        sao joao da barra -21.6403  -41.0511     23.51        92
# 484      484                 maragogi  -9.0122  -35.2225     25.07        76
# 492      492                   touros  -5.1989  -35.4608     26.64        66
# 496      496                   talara  -4.5772  -81.2719     22.42        83
# 503      503                piacabucu -10.4056  -36.4344     24.72        80
# 506      506                    alofi -19.0595 -169.9187     26.94        65
# 520      520                  garissa  -0.4536   39.6401     25.23        80
# 535      535          arraial do cabo -22.9661  -42.0278     23.40        93
# 547      547                    prado -17.3411  -39.2208     24.57        83
# 549      549                 ghadamis  30.1337    9.5007     23.51        22
#
#      Cloudiness  Wind Speed Country        Date
# 3            18        8.47      NC  1970-01-01
# 12           99        5.94      PN  1970-01-01
# 42          100        7.12      PF  1970-01-01
# 56          100        5.23      SO  1970-01-01
# 93           85        5.10      GF  1970-01-01
# 97           40        6.17      CK  1970-01-01
# 105          20        8.23      MG  1970-01-01
# 125          20        6.17      US  1970-01-01
# 128          89        4.78      JP  1970-01-01
# 135          75        8.23      CC  1970-01-01
# 144           4        8.57      BR  1970-01-01
# 146          87        6.55      BR  1970-01-01
# 147          59        5.00      NC  1970-01-01
# 149           2        5.15      MX  1970-01-01
# 150          75        5.14      BR  1970-01-01
# 160          20        6.17      US  1970-01-01
# 185          41        7.04      CV  1970-01-01
# 196          21        4.59      RE  1970-01-01
# 206          86        5.62      BR  1970-01-01
# 213          96        5.27      EC  1970-01-01
# 254          54        8.21      BR  1970-01-01
# 258          86        4.92      NE  1970-01-01
# 261         100        5.04      PF  1970-01-01
# 274         100        6.51      BR  1970-01-01
# 277         100        5.66      CX  1970-01-01
# 332          13        6.46      MG  1970-01-01
# 341           7        6.38      AU  1970-01-01
# 352          75        4.63      US  1970-01-01
# 361          40        5.14      AU  1970-01-01
# 391          20        5.66      JP  1970-01-01
# 408         100        4.70      BR  1970-01-01
# 425          41        5.72      AU  1970-01-01
# 442          12        9.36      US  1970-01-01
# 452         100        8.73      BR  1970-01-01
# 484         100        5.27      BR  1970-01-01
# 492          91        7.17      BR  1970-01-01
# 496          75        5.14      PE  1970-01-01
# 503         100        5.16      BR  1970-01-01
# 506          63        7.20      NU  1970-01-01
# 520          87        4.82      KE  1970-01-01
# 535          99       13.76      BR  1970-01-01
# 547          91        5.10      BR  1970-01-01
# 549          27        4.67      LY  1970-01-01

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = ideal_weather_df[["City", "Country", "Lat", "Lng", "Humidity"]].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"]=""

# Display sample data
hotel_df
# Out:
#                             City Country      Lat       Lng  Humidity  \
# 4              port-aux-francais      TF -49.3500   70.2167        94
# 8    edinburgh of the seven seas      SH -37.0676  -12.3116        70
# 18                      la junta      US  37.9850 -103.5438        60
# 28                       ushuaia      AR -54.8000  -68.3000        65
# 31                         ancud      CL -41.8697  -73.8203        79
# 49                    bredasdorp      ZA -34.5322   20.0403        48
# 51                      fisterra      ES  42.9049   -9.2629        60
# 53                        kodiak      US  57.7900 -152.4072        93
# 86                          orel      RU  52.9658   36.0803        95
# 104               puerto deseado      AR -47.7503  -65.8938        28
# 106                      peniche      PT  39.3558   -9.3811        90
# 116         vila franca do campo      PT  37.7167  -25.4333        99
# 117                   mandalgovi      MN  45.7625  106.2708        39
# 118               margaret river      AU -33.9500  115.0667        70
# 123                      colonia      DE  50.9333    6.9500        79
# 124                  taldykorgan      KZ  45.0156   78.3739        88
# 131                     la passe      FR  45.5549   -0.8967        84
# 140                      viveiro      ES  43.6623   -7.5934        77
# 143                        gaspe      CA  48.8334  -64.4819        65
# 157                       viedma      AR -40.8135  -62.9967        38
# 174                  east london      ZA -33.0153   27.9116        55
# 198                         lebu      CL -37.6167  -73.6500        70
# 201                  mount pearl      CA  47.5166  -52.7813        89
# 223                 port lincoln      AU -34.7333  135.8667        50
# 257                   st. john's      CA  47.5649  -52.7093        90
# 263                  port alfred      ZA -33.5906   26.8910        55
# 317                         nuuk      GL  64.1835  -51.7216        74
# 321                      stanley      GB  54.8680   -1.6985        95
# 343                 corner brook      CA  48.9667  -57.9484        94
# 345                   mossel bay      ZA -34.1831   22.1460        55
# 350                       hasaki      JP  35.7333  140.8333        59
# 365                      dalhart      US  36.0595 -102.5133        93
# 390         conception bay south      CA  47.4999  -52.9981        89
# 395                    changling      CN  44.2653  124.0005        42
# 456                 gornozavodsk      RU  58.3758   58.3211        81
# 473            medina de rioseco      ES  41.8833   -5.0441        83
# 474                     klaksvik      FO  62.2266   -6.5890        70
# 479                      northam      GB  51.0333   -4.2167        86
# 483                    glace bay      CA  46.1969  -59.9570        80
# 511                       teruel      ES  40.6667   -0.6667        86
# 533                        segre      FR  47.6833   -0.8667        85
# 551                 richards bay      ZA -28.7830   32.0377        90
#
#     Hotel Name
# 4
# 8
# 18
# 28
# 31
# 49
# 51
# 53
# 86
# 104
# 106
# 116
# 117
# 118
# 123
# 124
# 131
# 140
# 143
# 157
# 174
# 198
# 201
# 223
# 257
# 263
# 317
# 321
# 343
# 345
# 350
# 365
# 390
# 395
# 456
# 473
# 474
# 479
# 483
# 511
# 533
# 551

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {"categories": "accommodation.hotel",\
        "apiKey":geoapify_key, \
        "limit":1
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    longitude = row["Lng"]
    latitude = row["Lat"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"

    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# port-aux-francais - nearest hotel: No hotel found
# edinburgh of the seven seas - nearest hotel: No hotel found
# la junta - nearest hotel: No hotel found
# ushuaia - nearest hotel: No hotel found
# ancud - nearest hotel: No hotel found
# bredasdorp - nearest hotel: No hotel found
# fisterra - nearest hotel: No hotel found
# kodiak - nearest hotel: No hotel found
# orel - nearest hotel: No hotel found
# puerto deseado - nearest hotel: No hotel found
# peniche - nearest hotel: No hotel found
# vila franca do campo - nearest hotel: No hotel found
# mandalgovi - nearest hotel: No hotel found
# margaret river - nearest hotel: No hotel found
# colonia - nearest hotel: No hotel found
# taldykorgan - nearest hotel: No hotel found
# la passe - nearest hotel: No hotel found
# viveiro - nearest hotel: No hotel found
# gaspe - nearest hotel: No hotel found
# viedma - nearest hotel: No hotel found
# east london - nearest hotel: No hotel found
# lebu - nearest hotel: No hotel found
# mount pearl - nearest hotel: No hotel found
# port lincoln - nearest hotel: No hotel found
# st. john's - nearest hotel: No hotel found
# port alfred - nearest hotel: No hotel found
# nuuk - nearest hotel: No hotel found
# stanley - nearest hotel: No hotel found
# corner brook - nearest hotel: No hotel found
# mossel bay - nearest hotel: No hotel found
# hasaki - nearest hotel: No hotel found
# dalhart - nearest hotel: No hotel found
# conception bay south - nearest hotel: No hotel found
# changling - nearest hotel: No hotel found
# gornozavodsk - nearest hotel: No hotel found
# medina de rioseco - nearest hotel: No hotel found
# klaksvik - nearest hotel: No hotel found
# northam - nearest hotel: No hotel found
# glace bay - nearest hotel: No hotel found
# teruel - nearest hotel: No hotel found
# segre - nearest hotel: No hotel found
# richards bay - nearest hotel: No hotel found
#                             City Country      Lat       Lng  Humidity  \
# 4              port-aux-francais      TF -49.3500   70.2167        94
# 8    edinburgh of the seven seas      SH -37.0676  -12.3116        70
# 18                      la junta      US  37.9850 -103.5438        60
# 28                       ushuaia      AR -54.8000  -68.3000        65
# 31                         ancud      CL -41.8697  -73.8203        79
# 49                    bredasdorp      ZA -34.5322   20.0403        48
# 51                      fisterra      ES  42.9049   -9.2629        60
# 53                        kodiak      US  57.7900 -152.4072        93
# 86                          orel      RU  52.9658   36.0803        95
# 104               puerto deseado      AR -47.7503  -65.8938        28
# 106                      peniche      PT  39.3558   -9.3811        90
# 116         vila franca do campo      PT  37.7167  -25.4333        99
# 117                   mandalgovi      MN  45.7625  106.2708        39
# 118               margaret river      AU -33.9500  115.0667        70
# 123                      colonia      DE  50.9333    6.9500        79
# 124                  taldykorgan      KZ  45.0156   78.3739        88
# 131                     la passe      FR  45.5549   -0.8967        84
# 140                      viveiro      ES  43.6623   -7.5934        77
# 143                        gaspe      CA  48.8334  -64.4819        65
# 157                       viedma      AR -40.8135  -62.9967        38
# 174                  east london      ZA -33.0153   27.9116        55
# 198                         lebu      CL -37.6167  -73.6500        70
# 201                  mount pearl      CA  47.5166  -52.7813        89
# 223                 port lincoln      AU -34.7333  135.8667        50
# 257                   st. john's      CA  47.5649  -52.7093        90
# 263                  port alfred      ZA -33.5906   26.8910        55
# 317                         nuuk      GL  64.1835  -51.7216        74
# 321                      stanley      GB  54.8680   -1.6985        95
# 343                 corner brook      CA  48.9667  -57.9484        94
# 345                   mossel bay      ZA -34.1831   22.1460        55
# 350                       hasaki      JP  35.7333  140.8333        59
# 365                      dalhart      US  36.0595 -102.5133        93
# 390         conception bay south      CA  47.4999  -52.9981        89
# 395                    changling      CN  44.2653  124.0005        42
# 456                 gornozavodsk      RU  58.3758   58.3211        81
# 473            medina de rioseco      ES  41.8833   -5.0441        83
# 474                     klaksvik      FO  62.2266   -6.5890        70
# 479                      northam      GB  51.0333   -4.2167        86
# 483                    glace bay      CA  46.1969  -59.9570        80
# 511                       teruel      ES  40.6667   -0.6667        86
# 533                        segre      FR  47.6833   -0.8667        85
# 551                 richards bay      ZA -28.7830   32.0377        90
#
#          Hotel Name
# 4    No hotel found
# 8    No hotel found
# 18   No hotel found
# 28   No hotel found
# 31   No hotel found
# 49   No hotel found
# 51   No hotel found
# 53   No hotel found
# 86   No hotel found
# 104  No hotel found
# 106  No hotel found
# 116  No hotel found
# 117  No hotel found
# 118  No hotel found
# 123  No hotel found
# 124  No hotel found
# 131  No hotel found
# 140  No hotel found
# 143  No hotel found
# 157  No hotel found
# 174  No hotel found
# 198  No hotel found
# 201  No hotel found
# 223  No hotel found
# 257  No hotel found
# 263  No hotel found
# 317  No hotel found
# 321  No hotel found
# 343  No hotel found
# 345  No hotel found
# 350  No hotel found
# 365  No hotel found
# 390  No hotel found
# 395  No hotel found
# 456  No hotel found
# 473  No hotel found
# 474  No hotel found
# 479  No hotel found
# 483  No hotel found
# 511  No hotel found
# 533  No hotel found
# 551  No hotel found

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
# YOUR CODE HERE

# Display the map
# YOUR CODE HERE
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
